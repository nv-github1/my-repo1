# %% [markdown]
# <a href="https://colab.research.google.com/github/nv-github1/my-repo1/blob/master/Code_Stretch_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#"""
#Python Code Stretch: Data Types, Operators, and Files
#Starter Template
#"""

# --- 1. Working with Data Types ---
# Create five variables: int, float, str, bool, list
# Print each variable and its type
var_int = 7
var_float = 8.172
var_str = "Hello team!"
var_bool = True
var_list = [3, 4, 5, 6, 7]
print(var_int, type(var_int))
print(var_float, type(var_float))
print(var_str, type(var_str))
print(var_bool, type(var_bool))
print(var_list, type(var_list))

# --- 2. Playing with Operators ---
# Perform addition, subtraction, multiplication, division, exponentiation
# Store results in a dictionary with operation names as keys
# Print the dictionary
sum_result = var_int + var_float
sub_result = var_int - var_float
mul_result = var_int * var_float
div_result = var_int / var_float
exp_result = var_int ** var_float
operations = {
    "Addition": sum_result,
    "Subtraction": sub_result,
    "Multiplication": mul_result,
    "Division": div_result,
    "Exponentiation": exp_result
}
print(operations)

# --- 3. File Handling: Saving Results ---
# Open or create a file named "results.txt" in write mode
# Write each key-value pair from the dictionary to the file, one per line
# Close the file
file=open("results.txt", "w")
for key, value in operations.items():
    file.write(f"{key}: {value}\n")
file.close()


# --- 4. File Handling: Reading Results ---
# Reopen "results.txt" in read mode
# Read and print the contents
file=open("results.txt", "r")
print(file.read())
file.close()

# --- 5. Error Handling ---
# Try to open "missing.txt" in read mode
# Catch the error with try/except
# Print a friendly message if the file is missing
#try:
 #   print(open("missing.txt").read())
#except:
 #   print("The file does not exist.")
#file.close()

try:
  with open('missing.txt', 'r') as myfile:
    contents = myfile.read()   # read the file
    print(contents)            # print content
except FileNotFoundError:
    print('oh no, your file is missing')

# --- Stretch Challenge ---
# Read "results.txt" line by line into a list
# Combine each line with your string variable using +
file=open("results.txt", "r")
list_line=file.readline()
for line in list_line:
    print(line + var_str)
file.close()







# --- Additional Stretch Challenges ---

# 1. Converting Types
# Convert int -> float, float -> int
# Convert list -> tuple
# Convert string -> list of characters
# Print results with types
conv_int_float = float(var_int)
conv_float_int = int(var_float)
conv_list_tuple = tuple(var_list)
conv_str_list = list(var_str)
print(conv_int_float, type(conv_int_float))
print(conv_float_int, type(conv_float_int))
print(conv_list_tuple, type(conv_list_tuple))
print(conv_str_list, type(conv_str_list))

# 2. String Operations
# Concatenate string with boolean (convert bool to str)
# Repeat string 3 times
# Slice string to first three characters
conv_bool_str = str(var_bool)
print(var_str + conv_bool_str)
print(var_str * 3)
print(var_str[:3])

# 3. Dictionary Expansion
# Add modulus (%) and floor division (//) results
# Update and print dictionary

# 4. File Processing
# Count number of lines in results.txt
# Append "Completed successfully" at the end

# 5. Error Handling Variations
# Try dividing int by zero
# Catch ZeroDivisionError with a friendly message

# 6. Data Combination
# Create dictionary mapping variable names to their types
# Write this dictionary to a file called "types.txt"
# Out:
# 7 <class 'int'>
# 8.172 <class 'float'>
# Hello team! <class 'str'>
# True <class 'bool'>
# [3, 4, 5, 6, 7] <class 'list'>
# {'Addition': 15.172, 'Subtraction': -1.1720000000000006, 'Multiplication': 57.20400000000001, 'Division': 0.8565834557023984, 'Exponentiation': 8056403.0090591805}
# Addition: 15.172
# Subtraction: -1.1720000000000006
# Multiplication: 57.20400000000001
# Division: 0.8565834557023984
# Exponentiation: 8056403.0090591805
#
# oh no, your file is missing
# AHello team!
# dHello team!
# dHello team!
# iHello team!
# tHello team!
# iHello team!
# oHello team!
# nHello team!
# :Hello team!
#  Hello team!
# 1Hello team!
# 5Hello team!
# .Hello team!
# 1Hello team!
# 7Hello team!
# 2Hello team!
#
# Hello team!
# 7.0 <class 'float'>
# 8 <class 'int'>
# (3, 4, 5, 6, 7) <class 'tuple'>
# ['H', 'e', 'l', 'l', 'o', ' ', 't', 'e', 'a', 'm', '!'] <class 'list'>
# Hello team!True
# Hello team!Hello team!Hello team!
# Hel
